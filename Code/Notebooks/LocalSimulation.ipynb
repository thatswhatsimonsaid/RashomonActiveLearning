# %% [markdown]
# # Set Up

# %%
### Import Packages ###
import os
import math as math
import pandas as pd
import random as random

### Append Path ###
import sys
sys.path.append('..')

### Local Packages ###
from utils.Prediction import *
from utils.Selector import *
from utils.Auxiliary import *
from utils.Main import *

# %% [markdown]
# # Input

# %%
### Get Directory ###
cwd = os.getcwd()
ParentDirectory = os.path.abspath(os.path.join(cwd, ".."))

### DataType ###
DataTypeInput = "Haberman"                                                              # Options: [Iris, MONK1, MONK3, Bar7, COMPAS]

### Parameter Information ###
SimulationConfigInput = {"DataFileInput": DataTypeInput,
                            "Seed": 0,
                            "TestProportion": 0.2,
                            "CandidateProportion": 0.8,
                            "SelectorType": "TreeEnsembleQBCFunction",               # Options: [TreeEnsembleQBCFunction, PassiveLearning]
                            "ModelType": "TreeFarmsFunction",                        # Options: [TreeFarmsFunction, RandomForestClassificationFunction]
                            "UniqueErrorsInput": 0,                                  # Options: [0,1]
                            "n_estimators": 100,
                            "regularization": 0.01,
                            "RashomonThresholdType": "Adder",                        # Options: [Adder, Multiplier]
                            "RashomonThreshold": 0.015,
                            "Type": "Classification"
                            }

# %% [markdown]
# # Local Simulation

# %%
OneIterationResults = OneIterationFunction(SimulationConfigInput)
# Out:
# Iteration: 0/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 50
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.02083333395421505,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.1758333295583725,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.125,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1041666716337204,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.1758333444595337,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.02083333395421505,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.1758333295583725,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.125,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.1758333444595337,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.1041666716337204,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0625,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0833333358168602,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.1758333444595337,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.02083333395421505,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.125,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.1758333295583725,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0625,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.1758333444595337,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0833333358168602,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0625,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.1758333444595337,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0833333358168602,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0625,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0833333358168602,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.1758333444595337,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.1758333444595337,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.1041666716337204,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1041666716337204,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.1758333444595337,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.02083333395421505,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.125,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.1758333295583725,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 1/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 19
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06122449040412903,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.1728571355342865,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.08163265138864517,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06122449040412903,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.1728571355342865,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.08163265138864517,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06122449040412903,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.08163265138864517,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.1728571355342865,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "predIteration: 2/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 10
# iction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06122449040412903,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.08163265138864517,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.1728571355342865,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05999999865889549,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.17000000178813934,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.07999999821186066,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05999999865889549,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07999999821186066,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.17000000178813934,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 3/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 10
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05882353335618973,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.16725490987300873,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0784313753247261,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05882353335618973,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0784313753247261,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.16725490987300873,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 4/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 20
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07692307978868484,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.18384616076946259,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.07692307978868484,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07692307978868484,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07692307978868484,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.18384616076946259,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 5/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 10
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07547169923782349,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.18094339966773987,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.07547169923782349,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07547169923782349,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07547169923782349,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.18094339966773987,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 6/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 10
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07407407462596893,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.17814815044403076,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.07407407462596893,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07407407462596893,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.07407407462596893,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.17814815044403076,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 7/196
# null
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 361
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.036363635212183,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.19363635778427124,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.12727272510528564,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05454545468091965,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.19363635778427124,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.1090909093618393,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.09090908616781235,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.19363635778427124,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.072727270424366,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.036363635212183,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.19363635778427124,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.12727272510528564,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05454545468091965,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.19363635778427124,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.1090909093618393,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.09090908616781235,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.072727270424366,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.19363635778427124,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05454545468091965,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1090909093618393,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.19363635778427124,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.036363635212183,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.12727272510528564,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.19363635778427124,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05454545468091965,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1090909093618393,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.19363635778427124,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.036363635212183,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.12727272510528564,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.19363635778427124,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 8/196
# null
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 180
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0535714328289032,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.1907142996788025,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.1071428656578064,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0535714328289032,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.1907142996788025,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.1071428656578064,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0892857164144516,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 5,
#   "model_objective": 0.1907142996788025,
#   "name": "PositiveNodes_leq_2",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0714285746216774,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0892857164144516,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 5,
#     "name": "PositiveNodes_leq_2",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0714285746216774,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.1907142996788025,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0535714328289032,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1071428656578064,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.1907142996788025,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0535714328289032,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1071428656578064,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.1907142996788025,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 9/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 19
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05263157933950424,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.18789473176002502,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.10526315867900848,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05263157933950424,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.18789473176002502,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.10526315867900848,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05263157933950424,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.10526315867900848,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.18789473176002502,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.05263157933950424,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.10526315867900848,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.18789473176002502,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 10/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 19
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.051724135875701904,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.20241379737854004,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.12068965286016464,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.051724135875701904,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.12068965286016464,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.20241379737854004,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.051724135875701904,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.20241379737854004,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.12068965286016464,
#     "name": "Y",
#    Iteration: 11/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 19
#  "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.051724135875701904,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.12068965286016464,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.20241379737854004,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.050847455859184265,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.19949153065681458,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.11864406615495682,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.050847455859184265,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.19949153065681458,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.11864406615495682,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.050847455859184265,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.11864406615495682,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.19949153065681458,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.050847455859184265,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.11864406615495682,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.19949153065681458,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 12/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 41
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.03333333507180214,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.21333333849906921,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.15000000596046448,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06666667014360428,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.21333333849906921,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.11666667461395264,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06666667014360428,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.11666667461395264,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.21333333849906921,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.03333333507180214,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.21333333849906921,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.15000000596046448,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.03333333507180214,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.15000000596046448,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.21333333849906921,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06666667014360428,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 6,
#   "model_objective": 0.21333333849906921,
#   "name": "PositiveNodes_leq_4",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.11666667461395264,
#     "name"Iteration: 13/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 26
# : "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.06666667014360428,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 6,
#     "name": "PositiveNodes_leq_4",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.11666667461395264,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.21333333849906921,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.03333333507180214,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.15000000596046448,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.21333333849906921,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.032786883413791656,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.2103278636932373,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14754097163677216,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.032786883413791656,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.2103278636932373,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14754097163677216,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.032786883413791656,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14754097163677216,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.2103278636932373,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.032786883413791656,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14754097163677216,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.2103278636932373,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "coIteration: 14/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 23
# mplexity": 0.009999999776482582,
#     "loss": 0.0,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.032258063554763794,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.20741935074329376,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14516128599643707,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.032258063554763794,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.20741935074329376,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14516128599643707,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.032258063554763794,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
# ...
#     "loss": 0.15126051008701324,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.042016807943582535,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1428571492433548,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.2274789959192276,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.01260504312813282,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.042016807943582535,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14705882966518402,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.2274789959192276,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.008403361774981022,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 191/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 41
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04184100404381752,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0041841003112494946,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22665271162986755,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.15062761306762695,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04184100404381752,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0041841003112494946,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22665271162986755,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.15062761306762695,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04184100404381752,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1422594040632248,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.22665271162986755,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.012552300468087196,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04184100404381752,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14644351601600647,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.22665271162986755,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.008368200622498989,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 192/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 41
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.004166666883975267,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22583334147930145,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.15000000596046448,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.004166666883975267,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22583334147930145,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.15000000596046448,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14166668057441711,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.22583335638046265,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "lossIteration: 193/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 41
# ": 0.01250000111758709,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.0416666679084301,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.1458333432674408,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.22583335638046265,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.008333333767950535,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04149377718567848,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.004149377811700106,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22502075135707855,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14937759935855865,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04149377718567848,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.004149377811700106,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22502075135707855,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14937759935855865,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04149377718567848,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14107884466648102,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.22502075135707855,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.012448133900761604,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.04149377718567848,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14522822201251984,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.22502075135707855,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.008298755623400211,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# Iteration: 194/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 41
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041322313249111176,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.00413223123177886,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22421486675739288,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14876031875610352,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041322313249111176,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.00413223123177886,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22421486675739288,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14876031875610352,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041322313249111176,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14049586653709412,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.22421488165855408,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "Iteration: 195/196
# treefarms reported successful execution
# training completed. Number of trees in the Rashomon set: 41
# loss": 0.012396693229675293,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041322313249111176,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14462809264659882,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.22421486675739288,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.00826446246355772,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# null
# Finding Optimal Objective...
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041152261197566986,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 1,
#     "name": "Age_leq_40",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.004115226212888956,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22341564297676086,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14814814925193787,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041152261197566986,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.13991768658161163,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 1,
#   "model_objective": 0.22341561317443848,
#   "name": "Age_leq_40",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.012345679104328156,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041152261197566986,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 0,
#     "name": "Age_leq_38",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.004115226212888956,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 7,
#   "model_objective": 0.22341564297676086,
#   "name": "PositiveNodes_leq_8",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.14814814925193787,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }
# {
#   "false": {
#     "false": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.041152261197566986,
#       "name": "Y",
#       "prediction": 1
#     },
#     "feature": 7,
#     "name": "PositiveNodes_leq_8",
#     "reference": 1,
#     "relation": "==",
#     "true": {
#       "complexity": 0.009999999776482582,
#       "loss": 0.14403291046619415,
#       "name": "Y",
#       "prediction": 0
#     },
#     "type": "integral"
#   },
#   "feature": 0,
#   "model_objective": 0.22341561317443848,
#   "name": "Age_leq_38",
#   "reference": 1,
#   "relation": "==",
#   "true": {
#     "complexity": 0.009999999776482582,
#     "loss": 0.008230452425777912,
#     "name": "Y",
#     "prediction": 0
#   },
#   "type": "integral"
# }

# %%
plt.plot(OneIterationResults["ErrorVec"])

# %% [markdown]
# ---
