# %% [markdown]
# # Set Up

# %%
### Import Packages ###
import os
import math as math
import pandas as pd
import random as random

### Append Path ###
import sys
sys.path.append('..')

### Local Packages ###
from utils.Prediction import *
from utils.Selector import *
from utils.Auxiliary import *
from utils.Main import *

# %% [markdown]
# # Input

# %%
### Get Directory ###
cwd = os.getcwd()
ParentDirectory = os.path.abspath(os.path.join(cwd, ".."))

### DataType ###
DataTypeInput = "Haberman"                                                              # Options: [Iris, MONK1, MONK3, Bar7, COMPAS]

### Parameter Information ###
SimulationConfigInput = {"DataFileInput": DataTypeInput,
                            "Seed": 0,
                            "TestProportion": 0.2,
                            "CandidateProportion": 0.8,
                            "SelectorType": "TreeEnsembleQBCFunction",               # Options: [TreeEnsembleQBCFunction, PassiveLearning]
                            "ModelType": "RandomForestClassificationFunction",                        # Options: [TreeFarmsFunction, RandomForestClassificationFunction]
                            "UniqueErrorsInput": 0,                                  # Options: [0,1]
                            "n_estimators": 100,
                            "regularization": 0.01,
                            "RashomonThresholdType": "Adder",                        # Options: [Adder, Multiplier]
                            "RashomonThreshold": 0.015,
                            "Type": "Classification"
                            }

# %% [markdown]
# # Local Simulation

# %%
OneIterationResults = OneIterationFunction(SimulationConfigInput)
# Out:
# Iteration: 0/196
# Iteration: 1/196
# Iteration: 2/196
# Iteration: 3/196
# Iteration: 4/196
# Iteration: 5/196
# Iteration: 6/196
# Iteration: 7/196
# Iteration: 8/196
# Iteration: 9/196
# Iteration: 10/196
# Iteration: 11/196
# Iteration: 12/196
# Iteration: 13/196
# Iteration: 14/196
# Iteration: 15/196
# Iteration: 16/196
# Iteration: 17/196
# Iteration: 18/196
# Iteration: 19/196
# Iteration: 20/196
# Iteration: 21/196
# Iteration: 22/196
# Iteration: 23/196
# Iteration: 24/196
# Iteration: 25/196
# Iteration: 26/196
# Iteration: 27/196
# Iteration: 28/196
# Iteration: 29/196
# Iteration: 30/196
# Iteration: 31/196
# Iteration: 32/196
# Iteration: 33/196
# Iteration: 34/196
# Iteration: 35/196
# Iteration: 36/196
# Iteration: 37/196
# Iteration: 38/196
# Iteration: 39/196
# Iteration: 40/196
# Iteration: 41/196
# Iteration: 42/196
# Iteration: 43/196
# Iteration: 44/196
# Iteration: 45/196
# Iteration: 46/196
# Iteration: 47/196
# Iteration: 48/196
# Iteration: 49/196
# ...

# %%
plt.plot(OneIterationResults["ErrorVec"])

# %% [markdown]
# ---
